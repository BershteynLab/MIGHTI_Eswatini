# %% [markdown]
# <a href="https://colab.research.google.com/github/BershteynLab/MIGHTI_Eswatini/blob/main/Estimation_p_death.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Estimating Annual Probability of Death (p_death) and Duration of Condition (dur_condition) for Conditions in MIGHTI
#
# ## Purpose
#
# This notebook guides users in estimating the annual conditional probability of death (p_death) and the average duration of disease (dur_condition) for health conditions, using publicly available data such as  Global Burden of Disease (GBD) data.
#
#
# ## Probability of death
#
# The `p_death` parameter represents the **annual conditional probability of death** for an individual who has the disease of interest (e.g., T2D). This is distinct from general mortality metrics reported in sources like the Global Burden of Disease (GBD), which often give:
#
# * Total number of deaths
# * Deaths as a percent of all deaths
# * Death rates per 100,000 population
#
# These must be transformed into a **conditional risk of death given disease**.
# \begin{align*}
#     \text{deaths} &= \frac{\text{deaths_per_100k} * \text{population}}{100,000}\\
#     \text{cases} &= \text{prevalence (%)} * \text{population}\\
#     \text{p_death} &= \frac{\text{deaths}}{\text{cases}}= \frac{\text{deaths_per_100k}}{\text{prevalence (%)}}
# \end{align*}
#
# \begin{align*}
#     \text{p_death} &= \frac{\text{deaths_per_100k}}{\text{prevalence (%)}}
# \end{align*}
#
#
# ## Duration of conditions
#
# The `dur_condition` parameter represents the **the estimated average duration of condition** in years, derived as:
#
# $$ \text{dur_condition} = \frac{\text{Prevalence}}{\text{Incidence}}$$

# %% [markdown]
# ## Example: Eswatini, T2D in 2007
#
# * GBD T2D death rate: 55.81 per 100,000
# * GBD T2D prevalence percent: 2.25%
# * GBD T2D prevalence rate: 2171.05
# * GBD T2D incidence rate: 177.33
#
# ![Screenshot 2025-07-17 at 8.19.31 PM.png](data:image/png;base64,...)

# %% [markdown]
# We selected 2007 as the baseline year to estimate condition duration and mortality parameters (dur_condition, p_death) **for chronic diseases in Eswatini in the absence of intervention**, reflecting pre-expansion levels of healthcare access. This decision is based on the observation that Eswatini's health system began scaling up substantially after 2010, particularly due to the integration of HIV care infrastructure and broader investment in noncommunicable disease (NCD) services. The World Health Organization (WHO) noted significant improvements in service coverage, health workforce, and facility readiness after 2010, with increasing integration of chronic disease management into primary health care.

# %%
# Basic Setup
def estimate_p_death(deaths_per_100k, prevalence_percent, population=1_000_000):

    if prevalence <= 0:
        raise ValueError("Prevalence must be greater than 0.")

    p_death = deaths_per_100k / 100_000 / prevalence_percent
    return p_death


def estimate_dur_condition(prevalence_rate, incidence_rate):

    if incidence <= 0:
        raise ValueError("Incidence must be greater than 0.")

    return prevalence_rate / incidence_rate

# %%
# Type 2 Diabetes

# Input values
deaths_per_100k = 55.81
prevalence_percent = 0.0225
prevalence = 2171.05
incidence = 177.33

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (T2D, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of T2D: {dur_condition:.2f} years")
# Out:
# Estimated p_death (T2D, Eswatini 2007): 0.0248 per year
# Estimated duration of T2D: 12.24 years

# %%
# Type 1 Diabetes

# Input values
deaths_per_100k = 0.71
prevalence_percent = 0.0021
prevalence = 200.64
incidence = 9.01

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (T1D, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of T1D: {dur_condition:.2f} years")
# Out:
# Estimated p_death (T1D, Eswatini 2007): 0.0034 per year
# Estimated duration of T1D: 22.27 years

# %%
# Cardiovascular Disease

# Input values
deaths_per_100k = 165.33
prevalence_percent = 0.0396
prevalence = 3818.88
incidence = 413.99

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (CardiovascularDisease, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of CardiovascularDisease: {dur_condition:.2f} years")
# Out:
# Estimated p_death (CardiovascularDisease, Eswatini 2007): 0.0418 per year
# Estimated duration of CardiovascularDisease: 9.22 years

# %%
# Cervical Cancer

# Input values
deaths_per_100k = 14.12
prevalence_perecent = 0.0008
prevalence = 75.32
incidence = 22.71

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (CardiovascularDisease, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of CardiovascularDisease: {dur_condition:.2f} years")
# Out:
# Estimated p_death (CardiovascularDisease, Eswatini 2007): 0.0036 per year
# Estimated duration of CardiovascularDisease: 3.32 years

# %%
# Prostate Cancer

# Input values
deaths_per_100k = 5.051
prevalence_perecent = 0.0002
prevalence = 22.932
incidence = 6.06

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (ProstateCancer, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of ProstateCancer: {dur_condition:.2f} years")
# Out:
# Estimated p_death (ProstateCancer, Eswatini 2007): 0.0013 per year
# Estimated duration of ProstateCancer: 3.78 years

# %%
# Colorectal Cancer

# Input values
deaths_per_100k = 7.223
prevalence_perecent = 0.0002
prevalence = 22.845
incidence = 8.084

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (ColorectalCancer, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of ColorectalCancer: {dur_condition:.2f} years")
# Out:
# Estimated p_death (ColorectalCancer, Eswatini 2007): 0.0018 per year
# Estimated duration of ColorectalCancer: 2.83 years

# %%
# Chronic Kidney Disease

# Input values
deaths_per_100k = 26.562
prevalence_perecent = 0.0504
prevalence = 4868.98
incidence = 94.154

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (ChronicKidneyDisease, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of ChronicKidneyDisease: {dur_condition:.2f} years")
# Out:
# Estimated p_death (ChronicKidneyDisease, Eswatini 2007): 0.0067 per year
# Estimated duration of ChronicKidneyDisease: 51.71 years

# %%
# Breast Cancer

# Input values
deaths_per_100k = 6.993
prevalence_perecent = 0.0007
prevalence = 64.509
incidence = 10.238

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (BreastCancer, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of BreastCancer: {dur_condition:.2f} years")
# Out:
# Estimated p_death (BreastCancer, Eswatini 2007): 0.0018 per year
# Estimated duration of BreastCancer: 6.30 years

# %%
# Lung Cancer

# Input values
deaths_per_100k = 11.405
prevalence_perecent = 0.00012
prevalence = 11.649
incidence = 11.241

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (LungCancer, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of LungCancer: {dur_condition:.2f} years")
# Out:
# Estimated p_death (LungCancer, Eswatini 2007): 0.0029 per year
# Estimated duration of LungCancer: 1.04 years

# %%
# Viral Hepatitis

# Input values
deaths_per_100k = 1.669
prevalence_perecent = 0.00492
prevalence = 474.711
incidence = 5524.094

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (ViralHepatitis, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of ViralHepatitis: {dur_condition:.2f} years")
# Out:
# Estimated p_death (ViralHepatitis, Eswatini 2007): 0.0004 per year
# Estimated duration of ViralHepatitis: 0.09 years

# %%
# Alcohol Use Disorder

# Input values
deaths_per_100k = 1.1137
prevalence_perecent = 0.0166
prevalence = 1602.716
incidence = 807.564

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (AlcoholUseDisorder, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of AlcoholUseDisorder: {dur_condition:.2f} years")
# Out:
# Estimated p_death (AlcoholUseDisorder, Eswatini 2007): 0.0003 per year
# Estimated duration of AlcoholUseDisorder: 1.98 years

# %%
# Chronic Liver Disease

# Input values
deaths_per_100k = 24.247
prevalence_perecent = 0.179
prevalence = 17322.84
incidence = 819.782

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (ChronicLiverDisease, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of ChronicLiverDisease: {dur_condition:.2f} years")
# Out:
# Estimated p_death (ChronicLiverDisease, Eswatini 2007): 0.0061 per year
# Estimated duration of ChronicLiverDisease: 21.13 years

# %%
# Asthma

# Input values
deaths_per_100k = 14.800
prevalence_perecent = 0.066
prevalence = 6353.63
incidence = 1013.355

# Estimate p_death and dur_condition
p_death = estimate_p_death(deaths_per_100k, prevalence_percent)
dur_condition = estimate_dur_condition(prevalence, incidence)

print(f"Estimated p_death (Asthma, Eswatini 2007): {p_death:.4f} per year")
print(f"Estimated duration of Asthma: {dur_condition:.2f} years")
# Out:
# Estimated p_death (Asthma, Eswatini 2007): 0.0037 per year
# Estimated duration of Asthma: 6.27 years

# %% [markdown]
# ####References
#
# Global Burden of Disease Collaborative Network. Global Burden of Disease Study 2021 (GBD 2021). Seattle, United States: Institute for Health Metrics and Evaluation (IHME), 2024.
#
# https://www.afro.who.int/countries/health-topics?country=877&utm_source=chatgpt.com
